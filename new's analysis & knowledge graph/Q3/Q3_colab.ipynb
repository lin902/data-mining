# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
company_df = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/5002/dsaa5002_project/KnowledgeGraph/hidy.nodes.company.csv')

compete_df = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/5002/dsaa5002_project/KnowledgeGraph/hidy.relationships.compete.csv')
dispute_df = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/5002/dsaa5002_project/KnowledgeGraph/hidy.relationships.dispute.csv')

cooperate_df = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/5002/dsaa5002_project/KnowledgeGraph/hidy.relationships.cooperate.csv')
invest_df = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/5002/dsaa5002_project/KnowledgeGraph/hidy.relationships.invest.csv')
same_industry_df = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/5002/dsaa5002_project/KnowledgeGraph/hidy.relationships.same_industry.csv')
supply_df = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/5002/dsaa5002_project/KnowledgeGraph/hidy.relationships.supply.csv')

# %%
neo4j-admin database import full graph1 --relationships=cooperate=E:/neo4j-community-5.14.0-windows/neo4j-community-5.14.0/import/hidy.relationships.cooperate.csv --relationships=dispute=E:/neo4j-community-5.14.0-windows/neo4j-community-5.14.0/import/hidy.relationships.dispute.csv --relationships=invest=E:/neo4j-community-5.14.0-windows/neo4j-community-5.14.0/import/hidy.relationships.invest.csv --relationships=same_industry=E:/neo4j-community-5.14.0-windows/neo4j-community-5.14.0/import/hidy.relationships.same_industry.csv --relationships=supply=E:/neo4j-community-5.14.0-windows/neo4j-community-5.14.0/import/hidy.relationships.supply.csv

# %%
from py2neo import Graph, Node, Relationship

# %%
# !apt-get install openjdk-11-jdk-headless -qq > /dev/null

# %%
# !wget -O neo4j.tar.gz https://neo4j.com/artifact.php?name=neo4j-community-4.3.5-unix.tar.gz
# !tar -xvzf neo4j.tar.gz
# !mv neo4j-community-4.3.5 /content/neo4j
# Out:
# --2023-11-25 01:56:18--  https://neo4j.com/artifact.php?name=neo4j-community-4.3.5-unix.tar.gz
# Resolving neo4j.com (neo4j.com)... 13.33.82.102, 13.33.82.68, 13.33.82.92, ...
# Connecting to neo4j.com (neo4j.com)|13.33.82.102|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://dist.neo4j.org/neo4j-community-4.3.5-unix.tar.gz [following]
# --2023-11-25 01:56:19--  https://dist.neo4j.org/neo4j-community-4.3.5-unix.tar.gz
# Resolving dist.neo4j.org (dist.neo4j.org)... 18.67.65.63, 18.67.65.60, 18.67.65.121, ...
# Connecting to dist.neo4j.org (dist.neo4j.org)|18.67.65.63|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 126532088 (121M) [application/x-tar]
# Saving to: ‘neo4j.tar.gz’
#
# neo4j.tar.gz        100%[===================>] 120.67M  43.8MB/s    in 2.8s
#
# 2023-11-25 01:56:22 (43.8 MB/s) - ‘neo4j.tar.gz’ saved [126532088/126532088]
#
# neo4j-community-4.3.5/
# neo4j-community-4.3.5/plugins/
# ...

# %%
# !/content/neo4j/bin/neo4j start
# Out:
# Directories in use:
# home:         /content/neo4j
# config:       /content/neo4j/conf
# logs:         /content/neo4j/logs
# plugins:      /content/neo4j/plugins
# import:       /content/neo4j/import
# data:         /content/neo4j/data
# certificates: /content/neo4j/certificates
# licenses:     /content/neo4j/licenses
# run:          /content/neo4j/run
# Starting Neo4j.
# Started neo4j (pid:758). It is available at http://localhost:7474
# There may be a short delay until the server is ready.

# %%
from google.colab.output import eval_js
print(eval_js("google.colab.kernel.proxyPort(7474)"))
# Out:
# https://6ftp6frn2xr-496ff2e9c6d22116-7474-colab.googleusercontent.com/

# %% [markdown]
# 要查看或修改 Neo4j 的配置文件，以下步骤操作：
#
# 打开 Neo4j 的安装目录。在你之前安装的 Colab 示例中，安装路径为 /content/neo4j。
#
# 导航到 conf 目录，其中包含 Neo4j 的配置文件。
#
# 打开 neo4j.conf 文件，该文件包含了 Neo4j 的配置选项。
#
# 183.234.63.34

# %%
# !pip install py2neo

from py2neo import Graph
from py2neo import cypher
# Neo4j 数据库的连接信息
uri = "bolt://localhost:7687"
username = "neo4j"
current_password = "neo4j"
new_password = "1a2b3c4d"

# 创建与数据库的连接
graph = Graph(uri=uri, auth=(username, current_password))

# %%
graph = Graph("bolt://<public_ip_address>:<port>", auth=("neo4j", "password"))

# %%
query = "MATCH (n:Person) RETURN n.name AS name"

result = graph.run(query)

for record in result:
    print(record["name"])
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-9-e94b6c9fcf6d> in <cell line: 4>()
#       2 query = "MATCH (n:Person) RETURN n.name AS name"
#       3
# ----> 4 result = graph.run(query)
#       5
#       6 for record in result:
#
# /usr/local/lib/python3.10/dist-packages/py2neo/database.py in run(self, cypher, parameters, **kwparameters)
#     403         :return:
#     404         """
# --> 405         return self.auto().run(cypher, parameters, **kwparameters)
#     406
#     407     def evaluate(self, cypher, parameters=None, **kwparameters):
#
# /usr/local/lib/python3.10/dist-packages/py2neo/database.py in run(self, cypher, parameters, **kwparameters)
#     990                                                   graph_name=self.graph.name,
#     991                                                   readonly=self.readonly)
# ...

# %%
# 修改密码
query = f"CALL dbms.changePassword('{new_password}')"
graph.run(query)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-7-8c6a8b47d5c6> in <cell line: 3>()
#       1 # 修改密码
#       2 query = f"CALL dbms.changePassword('{new_password}')"
# ----> 3 graph.run(query)
#
# /usr/local/lib/python3.10/dist-packages/py2neo/database.py in run(self, cypher, parameters, **kwparameters)
#     403         :return:
#     404         """
# --> 405         return self.auto().run(cypher, parameters, **kwparameters)
#     406
#     407     def evaluate(self, cypher, parameters=None, **kwparameters):
#
# /usr/local/lib/python3.10/dist-packages/py2neo/database.py in run(self, cypher, parameters, **kwparameters)
#     990                                                   graph_name=self.graph.name,
#     991                                                   readonly=self.readonly)
# --> 992             self._connector.pull(result, -1)
# ...

# %%
company_df.info

# %%
compete_df.info

# %%
dispute_df.info #同compete,单向关系

# %%
cooperate_df.info

# %%
invest_df.info

# %%
same_industry_df.info

# %%
supply_df.info
